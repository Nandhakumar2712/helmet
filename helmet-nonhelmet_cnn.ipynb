# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import glob

# %%
xml_ = glob.glob('/kaggle/input/helmet-detection/annotations/*.xml')

# %%
import xml.etree.ElementTree as ET
lst=[]
for data in xml_:
    with open(data) as f:
        d = f.read()
        xml_string = d


    root = ET.fromstring(xml_string)  # parse the XML string
   
    # iterate over all elements in the root
    for child in root:
        # access the object you're interested in by its tag
        if  child.tag == 'object' and (child.find('name').text == 'With Helmet'or child.find('name').text == 'Without Helmet'):
            # do something with the object...:
            lst.append(child.find('name').text)
            break

# %%
images=os.listdir('/kaggle/input/helmet-detection/images')
images=pd.DataFrame(images)
image=list(np.array(images).flatten())
image[:5]
# Out:
# ['BikesHelmets719.png',
#  'BikesHelmets219.png',
#  'BikesHelmets18.png',
#  'BikesHelmets283.png',
#  'BikesHelmets277.png']

# %%
lst[:5]
# Out:
# ['Without Helmet',
#  'With Helmet',
#  'Without Helmet',
#  'Without Helmet',
#  'Without Helmet']

# %%
data = pd.DataFrame({'filename': image[:761], 'classes': lst})
data
# Out:
#                 filename         classes
# 0    BikesHelmets719.png  Without Helmet
# 1    BikesHelmets219.png     With Helmet
# 2     BikesHelmets18.png  Without Helmet
# 3    BikesHelmets283.png  Without Helmet
# 4    BikesHelmets277.png  Without Helmet
# ..                   ...             ...
# 756  BikesHelmets538.png     With Helmet
# 757   BikesHelmets30.png     With Helmet
# 758  BikesHelmets396.png  Without Helmet
# 759  BikesHelmets762.png     With Helmet
# 760  BikesHelmets337.png     With Helmet
#
# [761 rows x 2 columns]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
data_gen=ImageDataGenerator(rotation_range=0.2,zoom_range=0.2,
                           horizontal_flip=True,rescale=1/255)

# %%
data_gen.flow_from_dataframe(data,'/kaggle/input/helmet-detection/images',x_col='filename',y_col='classes',target_size=(100,100))
# Out:
# Found 761 validated image filenames belonging to 2 classes.

# %%
train_data=data_gen.flow_from_dataframe(df,'/kaggle/input/helmet-detection/images',x_col='filename',y_col='classes',target_size=(100,100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/3327729134.py in <module>
# ----> 1 train_data=data_gen.flow_from_dataframe(df,'/kaggle/input/helmet-detection/images',x_col='filename',y_col='classes',target_size=(100,100))
#
# NameError: name 'df' is not defined

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPool2D,Dense,Flatten

# %%
import tensorflow as tf

model=Sequential()
model.add(Conv2D(32,(3,3),input_shape=(120,120,3)))
model.add(MaxPool2D())
model.add(Conv2D(64,(3,3)))
model.add(MaxPool2D())
model.add(Conv2D(128,(3,3)))
model.add(MaxPool2D())
model.add(Conv2D(128,(3,3)))
model.add(MaxPool2D())
model.add(Conv2D(32,(3,3)))
model.add(MaxPool2D())
model.add(Flatten())
model.add(Dense(2,activation='softmax'))

model.compile(optimizer=tf.keras.optimizers.Adam(),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_data,epochs=5,batch_size=5)

# %% [markdown]
# > TESTING

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

img_path = '/kaggle/input/human-faces/Humans/1 (1).jpeg'
img = load_img(img_path, target_size=(120, 120))
img_array = img_to_array(img) / 255.0
img_array = img_array.reshape((1,) + img_array.shape)

# Make a prediction using the model
pred1 = model.predict(img_array)

# Print the predicted class
if pred1[0][1] > 0.5:
    print('Helmet')
else:
    print('No helmet')

# %%
pred1

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

img_path = '/kaggle/input/helmet-detection/images/BikesHelmets10.png'
img = load_img(img_path, target_size=(120, 120))
img_array = img_to_array(img) / 255.0
img_array = img_array.reshape((1,) + img_array.shape)

# Make a prediction using the model
pred = model.predict(img_array)

# Print the predicted class
if pred.any() > 0.5:
    print('Helmet')
else:
    print('No helmet')

# %%
pred

# %%
pred[0][0]
